# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt 
# charger img en niveau de gri
image = cv2.imread('guille-pozzi-SHcHVFhz7-M-unsplash.jpg')
# converion de img en niveau de gris
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# #apply gaussian filter
# blurred_image = cv2.GaussianBlur(gray_img, (5,5), 0)
# # détection de contours 
# image_canny = cv2.Canny(blurred_image, 10,180)

# #trouver et dessiner les contour des objets présents dans l'image
# contours, _ = cv2.findContours(image_canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# image_contours = np.copy(image)
# cv2.drawContours(image_contours, contours, -1, (0, 255, 0), 2)
plt.imshow(image_contours)
plt.show()

# corners
corners = cv2.goodFeaturesToTrack(image_contours, 100,0.01,15 )
corners = np.intp(corners)
for corner in corners:
    x,y=corner.ravel()
    cv2.circle(image_contours,(x,y),5,(0,0,255),-1)
    
cv2.imshow('image',image_contours)


# cv2.imshow('image originale', image)
# cv2.imshow('contour', image_contours)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 21
#      18 plt.show()
#      20 # corners
# ---> 21 corners = cv2.goodFeaturesToTrack(image_contours, 100,0.01,15 )
#      22 corners = np.intp(corners)
#      23 for corner in corners:
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\corner.cpp:254: error: (-215:Assertion failed) src.type() == CV_8UC1 || src.type() == CV_32FC1 in function 'cv::cornerEigenValsVecs'

# %% [markdown]
# algo de cami
# filtre gauien - enleve le bruit et img pus lisse
# moyenner : on enlève quasiment tout il garde les contours
#
# i on veut suppr bruit sans contour on utilise filtre gausien
#
# on doit trouver des gradients d'intensité
#
#
# le gradient -
